# %%
name = "ayukt"
print(name)
# Out:
# ayukt

# %%
age = 18
print(age)
# Out:
# 18

# %%
message = "I have Beautiful Potrait."
print(message)
# Out:
# I have Beautiful Potrait.

# %%
price = "19.99"
print(price)
# Out:
# 19.99

# %%
x, y, z = 10, 20, 30
print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %%
name = "akash"
result = name.upper() 
print(result)
# Out:
# AKASH

# %%
hometown = "LUCKNOW"
result = hometown.lower()
print(result)
# Out:
# lucknow

# %%
first_name = "Rahul"
last_name = "Sharma"
print(first_name + " " + last_name)
# Out:
# Rahul Sharma

# %%
name = "HelloWorld"
print(name[:5])
print(name[5:])
# Out:
# Hello
# World

# %%
marks = 95
print(marks)
# Out:
# 95

# %%
val1 = 5
val2 = 6
print("and operator:", val1 and val2)
# Out:
# and operator: 6

# %%
a = 5
b = 3
print(a>b)
# Out:
# True

# %%
a = float(input("Enter the first number: "))
b = float(input("Enter the second number: "))
sum = a + b

print("Sum:", sum)
# Out:
# Enter the first number:  4
# Enter the second number:  5
# Sum: 9.0

# %%
a = float(input("Enter the first number: "))
b = float(input("Enter the second number: "))
sum = a < b

print("Sum:", sum)
# Out:
# Enter the first number:  6
# Enter the second number:  3
# Sum: False

# %%
a = float(input("Enter num1: "))
b = float(input("Enter the num2: "))
divide = a / b

print("divide:", divide)
# Out:
# Enter num1:  4
# Enter the num2:  2
# divide: 2.0

# %%
a = input("enter the num1")
b = True
print(type(a))
print(type(b))
# Out:
# enter the num1 5
# <class 'str'>
# <class 'bool'>

# %%
age = 20
if age >= 18:
  print("You can vote")
else:
  print("You cannot vote")
# Out:
# You can vote

# %%
num = 6
if num % 2 == 0:
   print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
a = input("enter a num")
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# enter a num 1
# Even
