# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [10,20,30,40,50]

plt.plot(x,y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

# Original data points
x = np.array([1, 2, 3, 4, 5])
y = np.array([10, 25, 15, 30, 20])

# Generate 300 evenly spaced points for a smooth curve
x_smooth = np.linspace(x.min(), x.max(), 300)
spl = make_interp_spline(x, y, k=3)  # k=3 for cubic spline
y_smooth = spl(x_smooth)

# Plot
plt.plot(x_smooth, y_smooth, label="Smooth Curve", color="blue", linewidth=2)
plt.scatter(x, y, color="red", zorder=5, label="Data Points")  # Original points

plt.title("Smooth Curve through Points")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.legend()
plt.show()

# %%
x = [1,2,3,4,5]
y = [5,10,5,10,5]

plt.plot(x,y)

plt.show()

# %%
x = [1,2,3,4,5]
y = [5,10,5,15,10]

plt.plot(x,y)

plt.show()

# %%
x = [1,2,3,4,5]
y = [10,20,30,40,50]

plt.plot(x,y)

plt.show()

print("*")
# Out:
# *

# %%
students = ["Ayukt","Akash","Pinkee","Arushi"]
marks = [75,60,43,50]

plt.plot(students, marks)

plt.title("Student Marks")

plt.show()

# %%
students = ["Ayukt","Akash","Pinkee","Arushi"]
marks = [75,60,43,50]

plt.plot(students, marks)

plt.title("Student Marks")

plt.xlabel("Students")

plt.ylabel("Marks")

plt.show()

# %%
plt.plot(students,marks,color="green") #Change color

# %%
plt.plot(students,marks,linewidth=5)   #Change Line Width

# %%
plt.plot(students,marks,linestyle="--")   #Change Line Style

# %%
plt.plot(students,marks,marker="o")   #Add Markers

# %%
import matplotlib.pyplot as plt
students = ["Amit","Rahul","Priya","Neha"]
marks = [75,82,91,68]
plt.plot(
students,
marks,
color="blue",
linewidth=3,
linestyle="--",
marker="o"
)
plt.title("Student Marks")
# Out:
# Text(0.5, 1.0, 'Student Marks')

# %%
#Bar Chart

import matplotlib.pyplot as plt 
students = ["Amit","Rahul","Priya","Neha"] 
marks = [75,82,91,68] 

plt.bar(students, marks) 

plt.show()

# %%
plt.bar(students, marks, color="orange")
# Out:
# <BarContainer object of 4 artists>

# %%
#Pie Chart

import matplotlib.pyplot as plt  
subjects = ["Math","Science","English"]  
marks = [40,35,25] 

plt.pie(marks, labels=subjects) 

plt.show()

# %%
plt.pie(
    marks,     labels=subjects,     autopct="%1.1f%%" )   #Show Percentage

plt.show()

# %%
import matplotlib.pyplot as plt 
hours = [1,2,3,4,5] 
marks = [40,50,65,75,90] 

plt.scatter(hours, marks) 

plt.show()

# %%
import matplotlib.pyplot as plt 
marks = [45,55,67,78,88,67,78,90,45,55,67] 

plt.hist(marks)     #Histogram

plt.show()

# %%
#Multiple Line

import matplotlib.pyplot as plt 
months = [1,2,3,4,5] 
sales1 = [10,20,25,35,40] 
sales2 = [15,18,30,32,45] 
plt.plot(months, sales1) 
plt.plot(months, sales2) 
plt.show()

# %%
#Heat Map

import matplotlib.pyplot as plt
import numpy as np

data = np.array([
    [90,80,70],
    [60,50,40],
    [40,39,40],
    [43,35,69]
])

plt.imshow(data)

plt.show()

# %%
#Heat Map

import matplotlib.pyplot as plt
import numpy as np

data = np.array([
    [90,80,70],
    [60,50,40],
    [40,39,40],
    [43,35,69]
])

plt.imshow(data)
plt.colorbar()  #Add Colour Bar
plt.show()

# %%
#Bar Chart

import matplotlib.pyplot as plt 
students = ["Amit","Rahul","Priya","Neha"] 
marks = [75,82,91,68] 

plt.bar(students, marks) 

plt.show()

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3]
y = [20, 30, 40]

plt.plot(x, y)
plt.show()
